# %%
# %pip install chromadb
# %pip install llama-index chromadb
# %pip install llama-index-vector-stores-chroma
# Out:
# Requirement already satisfied: chromadb in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (0.5.9)
# Requirement already satisfied: build>=1.0.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (2.9.2)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (0.111.0)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.30.6)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (3.7.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (4.11.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (1.20.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (4.67.0)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (1.67.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (4.2.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (0.13.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (31.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (3.10.11)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: packaging>=19.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from build>=1.0.3->chromadb) (23.2)
# Requirement already satisfied: pyproject_hooks in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.0.5)
# Requirement already satisfied: jinja2>=2.11.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from fastapi>=0.95.2->chromadb) (3.1.4)
# Requirement already satisfied: python-multipart>=0.0.7 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.0.9)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from fastapi>=0.95.2->chromadb) (5.10.0)
# Requirement already satisfied: email_validator>=2.0.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from fastapi>=0.95.2->chromadb) (2.2.0)
# Requirement already satisfied: anyio in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx>=0.27.0->chromadb) (4.6.2.post1)
# Requirement already satisfied: certifi in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx>=0.27.0->chromadb) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.6)
# Requirement already satisfied: idna in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: sniffio in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.36.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Requirement already satisfied: requests-oauthlib in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Requirement already satisfied: durationpy>=0.7 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: coloredlogs in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.5)
# Requirement already satisfied: sympy in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.4.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.63.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.48b0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.48b0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-util-http==0.48b0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (75.1.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from pydantic>=1.9->chromadb) (2.23.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from rich>=10.11.0->chromadb) (2.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.26.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (14.0)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from email_validator>=2.0.0->fastapi>=0.95.2->chromadb) (2.7.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.9.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from jinja2>=2.11.2->fastapi>=0.95.2->chromadb) (3.0.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: llama-index in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (0.11.23)
# Requirement already satisfied: chromadb in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (0.5.9)
# Requirement already satisfied: llama-index-agent-openai<0.4.0,>=0.3.4 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.3.4)
# Requirement already satisfied: llama-index-cli<0.4.0,>=0.3.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.23 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.11.23)
# Requirement already satisfied: llama-index-embeddings-openai<0.3.0,>=0.2.4 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.2.5)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.9.48.post4)
# Requirement already satisfied: llama-index-llms-openai<0.3.0,>=0.2.10 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.2.16)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.3.0,>=0.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.2.3)
# Requirement already satisfied: llama-index-program-openai<0.3.0,>=0.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.2.0)
# Requirement already satisfied: llama-index-question-gen-openai<0.3.0,>=0.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.2.0)
# Requirement already satisfied: llama-index-readers-file<0.4.0,>=0.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: nltk>3.8.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (3.9.1)
# Requirement already satisfied: build>=1.0.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (2.9.2)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (0.111.0)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.30.6)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (3.7.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (4.11.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (1.20.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (4.67.0)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (1.67.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (4.2.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (0.13.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (31.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (3.10.11)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: packaging>=19.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from build>=1.0.3->chromadb) (23.2)
# Requirement already satisfied: pyproject_hooks in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.0.5)
# Requirement already satisfied: jinja2>=2.11.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from fastapi>=0.95.2->chromadb) (3.1.4)
# Requirement already satisfied: python-multipart>=0.0.7 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.0.9)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from fastapi>=0.95.2->chromadb) (5.10.0)
# Requirement already satisfied: email_validator>=2.0.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from fastapi>=0.95.2->chromadb) (2.2.0)
# Requirement already satisfied: anyio in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx>=0.27.0->chromadb) (4.6.2.post1)
# Requirement already satisfied: certifi in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx>=0.27.0->chromadb) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.6)
# Requirement already satisfied: idna in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: sniffio in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.36.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Requirement already satisfied: requests-oauthlib in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Requirement already satisfied: durationpy>=0.7 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: openai>=1.14.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-agent-openai<0.4.0,>=0.3.4->llama-index) (1.54.3)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.23->llama-index) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (3.10.8)
# Requirement already satisfied: dataclasses-json in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (2024.9.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (3.4.2)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (11.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (0.8.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (1.16.0)
# Requirement already satisfied: llama-cloud>=0.0.11 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-indices-managed-llama-cloud>=0.3.0->llama-index) (0.1.4)
# Requirement already satisfied: pandas in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.2.3)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-readers-file<0.4.0,>=0.3.0->llama-index) (4.12.3)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-readers-file<0.4.0,>=0.3.0->llama-index) (5.1.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-readers-file<0.4.0,>=0.3.0->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-readers-llama-parse>=0.3.0->llama-index) (0.5.13)
# Requirement already satisfied: click in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from nltk>3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from nltk>3.8.1->llama-index) (2024.11.6)
# Requirement already satisfied: coloredlogs in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.5)
# Requirement already satisfied: sympy in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.4.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.63.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.48b0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.48b0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-util-http==0.48b0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.48b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (75.1.0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from pydantic>=1.9->chromadb) (2.23.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from rich>=10.11.0->chromadb) (2.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.26.2)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (14.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama-index) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama-index) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama-index) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama-index) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama-index) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.4.0,>=0.3.0->llama-index) (2.6)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from email_validator>=2.0.0->fastapi>=0.95.2->chromadb) (2.7.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.16.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from jinja2>=2.11.2->fastapi>=0.95.2->chromadb) (3.0.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama-index) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.23->llama-index) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.23->llama-index) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.23->llama-index) (3.23.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2024.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama-index) (0.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting llama-index-vector-stores-chroma
#   Downloading llama_index_vector_stores_chroma-0.4.0-py3-none-any.whl.metadata (696 bytes)
# Collecting chromadb>=0.5.17 (from llama-index-vector-stores-chroma)
#   Downloading chromadb-0.5.20-py3-none-any.whl.metadata (6.8 kB)
# Collecting llama-index-core<0.13.0,>=0.12.0 (from llama-index-vector-stores-chroma)
#   Using cached llama_index_core-0.12.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: build>=1.0.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (2.9.2)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.111.0)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.30.6)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (3.7.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (4.11.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.20.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.48b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.27.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (4.67.0)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.67.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (4.2.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.13.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (31.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (3.10.11)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (13.9.4)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (3.10.8)
# Requirement already satisfied: dataclasses-json in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (2024.9.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (3.9.1)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (11.0.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (2.32.3)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (0.8.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (1.17.1)
# Requirement already satisfied: packaging>=19.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from build>=1.0.3->chromadb>=0.5.17->llama-index-vector-stores-chroma) (23.2)
# ...
# Requirement already satisfied: email_validator>=2.0.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from fastapi>=0.95.2->chromadb>=0.5.17->llama-index-vector-stores-chroma) (2.2.0)
# Requirement already satisfied: anyio in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx>=0.27.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (4.6.2.post1)
# Requirement already satisfied: certifi in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx>=0.27.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx>=0.27.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.0.6)
# Requirement already satisfied: idna in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx>=0.27.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (3.10)
# Requirement already satisfied: sniffio in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx>=0.27.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (2.36.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (2.2.3)
# Requirement already satisfied: durationpy>=0.7 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.9)
# Requirement already satisfied: click in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (8.1.7)
# Requirement already satisfied: joblib in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (2024.11.6)
# Requirement already satisfied: coloredlogs in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.17->llama-index-vector-stores-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.17->llama-index-vector-stores-chroma) (24.3.25)
# Requirement already satisfied: protobuf in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.17->llama-index-vector-stores-chroma) (4.25.5)
# Requirement already satisfied: sympy in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.13.1)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (8.4.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.63.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.48b0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.48b0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.48b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.48b0)
# Requirement already satisfied: opentelemetry-util-http==0.48b0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.48b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (75.1.0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from posthog>=2.4.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from posthog>=2.4.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from pydantic>=1.9->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from pydantic>=1.9->chromadb>=0.5.17->llama-index-vector-stores-chroma) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (3.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from rich>=10.11.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from rich>=10.11.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (2.15.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (3.1.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from tokenizers>=0.13.2->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.26.2)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from typer>=0.9.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (1.0.0)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.17->llama-index-vector-stores-chroma) (14.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (3.23.1)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from email_validator>=2.0.0->fastapi>=0.95.2->chromadb>=0.5.17->llama-index-vector-stores-chroma) (2.7.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (4.9)
# Requirement already satisfied: filelock in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=0.5.17->llama-index-vector-stores-chroma) (3.16.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.2.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from jinja2>=2.11.2->fastapi>=0.95.2->chromadb>=0.5.17->llama-index-vector-stores-chroma) (3.0.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.1.2)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-chroma) (0.2.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.17->llama-index-vector-stores-chroma) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.17->llama-index-vector-stores-chroma) (3.5.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.6.1)
# Downloading llama_index_vector_stores_chroma-0.4.0-py3-none-any.whl (5.2 kB)
# Downloading chromadb-0.5.20-py3-none-any.whl (617 kB)
#    ---------------------------------------- 0.0/617.9 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/617.9 kB ? eta -:--:--
#    ---------------------------------------- 617.9/617.9 kB 4.6 MB/s eta 0:00:00
# Using cached llama_index_core-0.12.0-py3-none-any.whl (1.6 MB)
# Installing collected packages: llama-index-core, chromadb, llama-index-vector-stores-chroma
#   Attempting uninstall: llama-index-core
#     Found existing installation: llama-index-core 0.11.23
#     Uninstalling llama-index-core-0.11.23:
#       Successfully uninstalled llama-index-core-0.11.23
#   Attempting uninstall: chromadb
#     Found existing installation: chromadb 0.5.9
#     Uninstalling chromadb-0.5.9:
#       Successfully uninstalled chromadb-0.5.9
# Successfully installed chromadb-0.5.20 llama-index-core-0.12.0 llama-index-vector-stores-chroma-0.4.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llama-index 0.11.23 requires llama-index-core<0.12.0,>=0.11.23, but you have llama-index-core 0.12.0 which is incompatible.
# llama-index-agent-openai 0.3.4 requires llama-index-core<0.12.0,>=0.11.0, but you have llama-index-core 0.12.0 which is incompatible.
# llama-index-cli 0.3.1 requires llama-index-core<0.12.0,>=0.11.0, but you have llama-index-core 0.12.0 which is incompatible.
# llama-index-embeddings-ollama 0.3.1 requires llama-index-core<0.12.0,>=0.11.0, but you have llama-index-core 0.12.0 which is incompatible.
# llama-index-embeddings-openai 0.2.5 requires llama-index-core<0.12.0,>=0.11.0, but you have llama-index-core 0.12.0 which is incompatible.
# llama-index-indices-managed-llama-cloud 0.4.0 requires llama-index-core<0.12.0,>=0.11.13.post1, but you have llama-index-core 0.12.0 which is incompatible.
# llama-index-llms-ollama 0.3.6 requires llama-index-core<0.12.0,>=0.11.0, but you have llama-index-core 0.12.0 which is incompatible.
# llama-index-llms-openai 0.2.16 requires llama-index-core<0.12.0,>=0.11.7, but you have llama-index-core 0.12.0 which is incompatible.
# llama-index-multi-modal-llms-openai 0.2.3 requires llama-index-core<0.12.0,>=0.11.0, but you have llama-index-core 0.12.0 which is incompatible.
# llama-index-program-openai 0.2.0 requires llama-index-core<0.12.0,>=0.11.0, but you have llama-index-core 0.12.0 which is incompatible.
# llama-index-question-gen-openai 0.2.0 requires llama-index-core<0.12.0,>=0.11.0, but you have llama-index-core 0.12.0 which is incompatible.
# llama-index-readers-file 0.3.0 requires llama-index-core<0.12.0,>=0.11.0, but you have llama-index-core 0.12.0 which is incompatible.
# llama-index-readers-llama-parse 0.3.0 requires llama-index-core<0.12.0,>=0.11.0, but you have llama-index-core 0.12.0 which is incompatible.
# open-webui 0.3.35 requires chromadb==0.5.9, but you have chromadb 0.5.20 which is incompatible.
# open-webui 0.3.35 requires pypdf==4.3.1, but you have pypdf 5.1.0 which is incompatible.

# %%
import chromadb
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from llama_index.vector_stores.chroma import ChromaVectorStore
from llama_index.core import StorageContext
from llama_index.embeddings.ollama import OllamaEmbedding

# %%
documents = SimpleDirectoryReader(input_files=['../data_uber/uber_2021.pdf']).load_data()

# %%
db = chromadb.PersistentClient(path="./chroma_db")

# %%
chroma_collection = db.get_or_create_collection("first_collection")

# %%
vector_store = ChromaVectorStore(chroma_collection=chroma_collection)
storage_context = StorageContext.from_defaults(vector_store=vector_store)

# %%
index = VectorStoreIndex.from_documents(documents, storage_context=storage_context)
