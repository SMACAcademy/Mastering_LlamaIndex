# %%
# %pip install llama-index-llms-openai
# !pip install llama-index

import logging
import sys

logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

import nest_asyncio
nest_asyncio.apply()
# Out:
# Requirement already satisfied: llama-index-llms-openai in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (0.3.10)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.4 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-llms-openai) (0.12.5)
# Requirement already satisfied: openai<2.0.0,>=1.57.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-llms-openai) (1.57.4)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (3.10.8)
# Requirement already satisfied: dataclasses-json in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (2024.9.0)
# Requirement already satisfied: httpx in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (3.9.1)
# Requirement already satisfied: numpy in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (10.4.0)
# Requirement already satisfied: pydantic>=2.8.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (4.67.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (4.11.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (1.16.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from openai<2.0.0,>=1.57.1->llama-index-llms-openai) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from openai<2.0.0,>=1.57.1->llama-index-llms-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from openai<2.0.0,>=1.57.1->llama-index-llms-openai) (0.7.0)
# Requirement already satisfied: sniffio in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from openai<2.0.0,>=1.57.1->llama-index-llms-openai) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (1.17.1)
# Requirement already satisfied: idna>=2.8 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.57.1->llama-index-llms-openai) (3.10)
# Requirement already satisfied: certifi in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (0.14.0)
# Requirement already satisfied: click in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (8.1.7)
# Requirement already satisfied: joblib in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (3.1.1)
# Requirement already satisfied: colorama in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (3.23.1)
# Requirement already satisfied: packaging>=17.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (23.2)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.4->llama-index-llms-openai) (0.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: llama-index in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (0.11.23)
# Requirement already satisfied: llama-index-agent-openai<0.4.0,>=0.3.4 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.3.4)
# Requirement already satisfied: llama-index-cli<0.4.0,>=0.3.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.3.1)
# Collecting llama-index-core<0.12.0,>=0.11.23 (from llama-index)
#   Using cached llama_index_core-0.11.23-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: llama-index-embeddings-openai<0.3.0,>=0.2.4 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.2.5)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.9.48.post4)
# Collecting llama-index-llms-openai<0.3.0,>=0.2.10 (from llama-index)
#   Using cached llama_index_llms_openai-0.2.16-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.3.0,>=0.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.2.3)
# Requirement already satisfied: llama-index-program-openai<0.3.0,>=0.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.2.0)
# Requirement already satisfied: llama-index-question-gen-openai<0.3.0,>=0.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.2.0)
# Requirement already satisfied: llama-index-readers-file<0.4.0,>=0.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: nltk>3.8.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-agent-openai<0.4.0,>=0.3.4->llama-index) (1.57.4)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.23->llama-index) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (3.10.8)
# Requirement already satisfied: dataclasses-json in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (2024.9.0)
# Requirement already satisfied: httpx in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (3.4.2)
# Requirement already satisfied: numpy<2.0.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (4.67.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (4.11.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.12.0,>=0.11.23->llama-index) (1.16.0)
# Requirement already satisfied: llama-cloud>=0.0.11 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-indices-managed-llama-cloud>=0.3.0->llama-index) (0.1.4)
# Requirement already satisfied: pandas in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.2.3)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-readers-file<0.4.0,>=0.3.0->llama-index) (4.12.3)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-readers-file<0.4.0,>=0.3.0->llama-index) (5.1.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-readers-file<0.4.0,>=0.3.0->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-readers-llama-parse>=0.3.0->llama-index) (0.5.13)
# Requirement already satisfied: click in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from nltk>3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from nltk>3.8.1->llama-index) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama-index) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama-index) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama-index) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama-index) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama-index) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.4.0,>=0.3.0->llama-index) (2.6)
# Requirement already satisfied: anyio in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.23->llama-index) (4.6.2.post1)
# Requirement already satisfied: certifi in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.23->llama-index) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.23->llama-index) (1.0.6)
# Requirement already satisfied: idna in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.23->llama-index) (3.10)
# Requirement already satisfied: sniffio in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.23->llama-index) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.23->llama-index) (0.14.0)
# Requirement already satisfied: colorama in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from click->nltk>3.8.1->llama-index) (0.4.6)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama-index) (0.7.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.23->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.23->llama-index) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.23->llama-index) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.23->llama-index) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.23->llama-index) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.23->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.23->llama-index) (3.23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2024.2)
# Requirement already satisfied: packaging>=17.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.23->llama-index) (23.2)
# Requirement already satisfied: six>=1.5 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.23->llama-index) (0.2.0)
# Using cached llama_index_core-0.11.23-py3-none-any.whl (1.6 MB)
# Using cached llama_index_llms_openai-0.2.16-py3-none-any.whl (13 kB)
# Installing collected packages: llama-index-core, llama-index-llms-openai
#   Attempting uninstall: llama-index-core
#     Found existing installation: llama-index-core 0.12.5
#     Uninstalling llama-index-core-0.12.5:
#       Successfully uninstalled llama-index-core-0.12.5
#   Attempting uninstall: llama-index-llms-openai
#     Found existing installation: llama-index-llms-openai 0.3.10
#     Uninstalling llama-index-llms-openai-0.3.10:
#       Successfully uninstalled llama-index-llms-openai-0.3.10
# Successfully installed llama-index-core-0.11.23 llama-index-llms-openai-0.2.16
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llama-index-embeddings-cohere 0.4.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.11.23 which is incompatible.
# llama-index-embeddings-huggingface 0.4.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.11.23 which is incompatible.
# llama-index-extractors-entity 0.3.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.11.23 which is incompatible.
# llama-index-llms-anthropic 0.5.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.11.23 which is incompatible.
# llama-index-readers-database 0.3.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.11.23 which is incompatible.
# llama-index-readers-deeplake 0.3.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.11.23 which is incompatible.
# llama-index-retrievers-bm25 0.5.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.11.23 which is incompatible.
# llama-index-storage-docstore-mongodb 0.3.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.11.23 which is incompatible.
# llama-index-storage-docstore-redis 0.3.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.11.23 which is incompatible.
# llama-index-storage-index-store-mongodb 0.4.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.11.23 which is incompatible.
# llama-index-storage-index-store-redis 0.4.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.11.23 which is incompatible.
# llama-index-storage-kvstore-mongodb 0.3.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.11.23 which is incompatible.
# llama-index-storage-kvstore-redis 0.3.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.11.23 which is incompatible.
# llama-index-utils-workflow 0.3.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.11.23 which is incompatible.
# llama-index-vector-stores-redis 0.4.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.11.23 which is incompatible.

# %%
from llama_index.core import (
    PromptTemplate,
)

# %%
from llama_index.core import Settings
from llama_index.llms.ollama import Ollama
from llama_index.embeddings.ollama import OllamaEmbedding

# Configure Ollama LLM
ollama_llm = Ollama(
    model="llama3.2:latest",
    base_url="http://localhost:11434",
    temperature=0.1
)

# Configure embedding model
ollama_embedding = OllamaEmbedding(
    model_name="nomic-embed-text:latest",
    base_url="http://localhost:11434",
    ollama_additional_kwargs={"mirostat": 0}
)

Settings.llm = ollama_llm
Settings.embed_model = ollama_embedding
# Out:
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='C:\\Users\\Muthu\\.conda\\envs\\llamaindex\\Library\\ssl\\cacert.pem'
# load_verify_locations cafile='C:\\Users\\Muthu\\.conda\\envs\\llamaindex\\Library\\ssl\\cacert.pem'
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='C:\\Users\\Muthu\\.conda\\envs\\llamaindex\\Library\\ssl\\cacert.pem'
# load_verify_locations cafile='C:\\Users\\Muthu\\.conda\\envs\\llamaindex\\Library\\ssl\\cacert.pem'
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='C:\\Users\\Muthu\\.conda\\envs\\llamaindex\\Library\\ssl\\cacert.pem'
# load_verify_locations cafile='C:\\Users\\Muthu\\.conda\\envs\\llamaindex\\Library\\ssl\\cacert.pem'

# %%
import getpass
import os

os.environ["OPENAI_API_KEY"] = getpass.getpass("open ai api key: ")

# %%
from llama_index.llms.openai import OpenAI
llm = OpenAI(model="gpt-3.5-turbo")

# %%
from llama_index.core import SimpleDirectoryReader

documents = SimpleDirectoryReader(input_files=['../data/paul_graham_essay3.txt']).load_data()
# documents = SimpleDirectoryReader(input_files=['../data/2022 Q3 AAPL.pdf']).load_data()
# Out:
# DEBUG:fsspec.local:open file: e:/Learn2/workspace2/git_area/Mastering_LlamaIndex/7-Prompts/../data/paul_graham_essay3.txt
# open file: e:/Learn2/workspace2/git_area/Mastering_LlamaIndex/7-Prompts/../data/paul_graham_essay3.txt

# %%
from llama_index.core import VectorStoreIndex

# vector_index = VectorStoreIndex.from_documents(documents, embed_model=ollama_embedding)
vector_index = VectorStoreIndex.from_documents(documents)
# Out:
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: What I Worked On
#
# February 2021
#
# Before college...
# > Adding chunk: What I Worked On
#
# February 2021
#
# Before college...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: I couldn't have put this into words when I was ...
# > Adding chunk: I couldn't have put this into words when I was ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: So I looked around to see what I could salvage ...
# > Adding chunk: So I looked around to see what I could salvage ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: I didn't want to drop out of grad school, but h...
# > Adding chunk: I didn't want to drop out of grad school, but h...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: We actually had one of those little stoves, fed...
# > Adding chunk: We actually had one of those little stoves, fed...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: But Interleaf still had a few years to live yet...
# > Adding chunk: But Interleaf still had a few years to live yet...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Painting students were supposed to express them...
# > Adding chunk: Painting students were supposed to express them...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Meanwhile I'd been hearing more and more about ...
# > Adding chunk: Meanwhile I'd been hearing more and more about ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: In return for that and doing the initial legal ...
# > Adding chunk: In return for that and doing the initial legal ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Which meant being easy to use and inexpensive. ...
# > Adding chunk: Which meant being easy to use and inexpensive. ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Nor had I changed my grad student lifestyle sig...
# > Adding chunk: Nor had I changed my grad student lifestyle sig...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Now when I walked past charming little restaura...
# > Adding chunk: Now when I walked past charming little restaura...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: A lot of Lisp hackers dream of building a new L...
# > Adding chunk: A lot of Lisp hackers dream of building a new L...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: So while working on things that aren't prestigi...
# > Adding chunk: So while working on things that aren't prestigi...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: [13]
#
# Once again, ignorance worked in our favor...
# > Adding chunk: [13]
#
# Once again, ignorance worked in our favor...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: They were an impressive group. That first batch...
# > Adding chunk: They were an impressive group. That first batch...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: But while I continued to work a good deal in Ar...
# > Adding chunk: But while I continued to work a good deal in Ar...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: So if Sam said yes, we'd let him reorganize YC....
# > Adding chunk: So if Sam said yes, we'd let him reorganize YC....
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: That wouldn't have been feasible at the time. M...
# > Adding chunk: That wouldn't have been feasible at the time. M...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: I wrote an essay for myself to answer that ques...
# > Adding chunk: I wrote an essay for myself to answer that ques...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Publishing online means you treat the online ve...
# > Adding chunk: Publishing online means you treat the online ve...
# DEBUG:httpcore.connection:connect_tcp.started host='localhost' port=11434 local_address=None timeout=None socket_options=None
# connect_tcp.started host='localhost' port=11434 local_address=None timeout=None socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x000001E463EEDD10>
# connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x000001E463EEDD10>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:38 GMT'), (b'Transfer-Encoding', b'chunked')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:38 GMT'), (b'Transfer-Encoding', b'chunked')])
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:39 GMT'), (b'Transfer-Encoding', b'chunked')])
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:40 GMT'), (b'Transfer-Encoding', b'chunked')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:40 GMT'), (b'Transfer-Encoding', b'chunked')])
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:40 GMT'), (b'Transfer-Encoding', b'chunked')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:22:40 GMT'), (b'Transfer-Encoding', b'chunked')])
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete

# %%
qa_prompt_tmpl_str = """\
Context information is below.
---------------------
{context_str}
---------------------
Given the context information and not prior knowledge, answer the query.
Please write the answer in the style of {tone_name}
Query: {query_str}
Answer: \
"""

# %%
# Create a PromptTemplate object
prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str)

# Apply partial formatting to set the tone_name
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")

# %%
formatted_prompt = partial_prompt_tmpl.format(
    context_str="In this work, we develop and release Llama 2, a collection of pretrained and fine-tuned large language models (LLMs) ranging in scale from 7 billion to 70 billion parameters",
    query_str="How many params does Llama 2 have?"
)

# %%
response = vector_index.as_query_engine(
    llm=ollama_llm
).query(formatted_prompt)
# Out:
# DEBUG:httpcore.connection:close.started
# close.started
# DEBUG:httpcore.connection:close.complete
# close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='localhost' port=11434 local_address=None timeout=None socket_options=None
# connect_tcp.started host='localhost' port=11434 local_address=None timeout=None socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x000001E465CA55D0>
# connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x000001E465CA55D0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:25:26 GMT'), (b'Transfer-Encoding', b'chunked')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:25:26 GMT'), (b'Transfer-Encoding', b'chunked')])
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete
# DEBUG:llama_index.core.indices.utils:> Top 2 nodes:
# > [Node 858e7e0a-6f0e-4765-a109-4de84761c56d] [Similarity score:             0.551465] So if Sam said yes, we'd let him reorganize YC. Robert and I would retire, and Jessica and Trevor...
# > [Node 4537b061-d7eb-4bed-a0b4-1f99be996f65] [Similarity score:             0.534151] That wouldn't have been feasible at the time. McCarthy tested his interpreter by hand-simulating ...
# > Top 2 nodes:
# > [Node 858e7e0a-6f0e-4765-a109-4de84761c56d] [Similarity score:             0.551465] So if Sam said yes, we'd let him reorganize YC. Robert and I would retire, and Jessica and Trevor...
# > [Node 4537b061-d7eb-4bed-a0b4-1f99be996f65] [Similarity score:             0.534151] That wouldn't have been feasible at the time. McCarthy tested his interpreter by hand-simulating ...
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='C:\\Users\\Muthu\\.conda\\envs\\llamaindex\\Library\\ssl\\cacert.pem'
# load_verify_locations cafile='C:\\Users\\Muthu\\.conda\\envs\\llamaindex\\Library\\ssl\\cacert.pem'
# DEBUG:httpcore.connection:connect_tcp.started host='localhost' port=11434 local_address=None timeout=30.0 socket_options=None
# connect_tcp.started host='localhost' port=11434 local_address=None timeout=30.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x000001E465ED2E10>
# connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x000001E465ED2E10>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:25:31 GMT'), (b'Content-Length', b'642')])
# receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json; charset=utf-8'), (b'Date', b'Mon, 16 Dec 2024 03:25:31 GMT'), (b'Content-Length', b'642')])
# INFO:httpx:HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# response_closed.complete

# %%
print("\nResponse from the Query Engine:")
print(response)
# Out:
# Response from the Query Engine:
# Fair query, thou seekest knowledge of Llama 2's might,
# A collection of models, with parameters in sight.
#
# 'Tis said that Llama 2 doth boast a range most wide,
# From 7 billion to 70 billion parameters, side by side.
# A vast array, indeed, of computational power and art,
# That doth enable language models to converse and play their part.
