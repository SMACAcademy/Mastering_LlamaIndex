# %%
# !pip install llama-index
# !pip install traceloop-sdk



import logging
import sys

logging.basicConfig(stream=sys.stdout, level=logging.ERROR)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

import nest_asyncio
nest_asyncio.apply()
# Out:
# Requirement already satisfied: llama-index in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (0.12.6)
# Requirement already satisfied: llama-index-agent-openai<0.5.0,>=0.4.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: llama-index-cli<0.5.0,>=0.4.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.6 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.12.6)
# Requirement already satisfied: llama-index-embeddings-openai<0.4.0,>=0.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.6.3)
# Requirement already satisfied: llama-index-llms-openai<0.4.0,>=0.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.3.10)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.5.0,>=0.4.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: llama-index-program-openai<0.4.0,>=0.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-question-gen-openai<0.4.0,>=0.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: llama-index-readers-file<0.5.0,>=0.4.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.4.1)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: nltk>3.8.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.57.4)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.6->llama-index) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.6->llama-index) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.6->llama-index) (3.11.11)
# Requirement already satisfied: dataclasses-json in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.6->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.6->llama-index) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.6->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.6->llama-index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.6->llama-index) (2024.9.0)
# Requirement already satisfied: httpx in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.6->llama-index) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.6->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.6->llama-index) (3.4.2)
# Requirement already satisfied: numpy in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.6->llama-index) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.6->llama-index) (10.4.0)
# Requirement already satisfied: pydantic>=2.8.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.6->llama-index) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.6->llama-index) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.6->llama-index) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.6->llama-index) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.6->llama-index) (4.67.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.6->llama-index) (4.11.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.6->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-core<0.13.0,>=0.12.6->llama-index) (1.17.0)
# Requirement already satisfied: llama-cloud>=0.1.5 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (0.1.6)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (4.12.3)
# Requirement already satisfied: pandas in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.2.3)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (5.1.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index) (0.5.13)
# Requirement already satisfied: click in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from nltk>3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from nltk>3.8.1->llama-index) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.6->llama-index) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.6->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.6->llama-index) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.6->llama-index) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.6->llama-index) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.6->llama-index) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.6->llama-index) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.6)
# Requirement already satisfied: anyio in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.6->llama-index) (4.6.2.post1)
# Requirement already satisfied: certifi in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.6->llama-index) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.6->llama-index) (1.0.6)
# Requirement already satisfied: idna in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.6->llama-index) (3.10)
# Requirement already satisfied: sniffio in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.6->llama-index) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.6->llama-index) (0.14.0)
# Requirement already satisfied: colorama in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from click->nltk>3.8.1->llama-index) (0.4.6)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (0.7.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.6->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.6->llama-index) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.6->llama-index) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.6->llama-index) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.6->llama-index) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.6->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.6->llama-index) (3.23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2024.2)
# Requirement already satisfied: packaging>=17.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.6->llama-index) (23.2)
# Requirement already satisfied: six>=1.5 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (1.16.0)
# Requirement already satisfied: traceloop-sdk in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (0.34.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.10.9 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (3.11.11)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.4.6)
# Requirement already satisfied: deprecated<2.0.0,>=1.2.14 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (1.2.14)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (3.1.4)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.28.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.28.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.28.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-alephalpha==0.34.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation-anthropic==0.34.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation-bedrock==0.34.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation-chromadb==0.34.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation-cohere==0.34.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation-google-generativeai==0.34.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation-groq==0.34.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation-haystack==0.34.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation-lancedb==0.34.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation-langchain==0.34.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation-llamaindex==0.34.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation-logging>=0.50b0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation-marqo==0.34.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation-milvus==0.34.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation-mistralai==0.34.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation-ollama==0.34.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation-openai==0.34.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation-pinecone==0.34.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation-qdrant==0.34.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation-replicate==0.34.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation-requests>=0.50b0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation-sagemaker==0.34.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation-sqlalchemy>=0.50b0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation-threading>=0.50b0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation-together==0.34.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation-transformers==0.34.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib3>=0.50b0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation-vertexai==0.34.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation-watsonx==0.34.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation-weaviate==0.34.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.34.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.28.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (1.29.0)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai==0.4.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (0.4.2)
# Requirement already satisfied: posthog<4,>3.0.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (3.7.0)
# Requirement already satisfied: pydantic>=1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (2.9.2)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.3 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from traceloop-sdk) (8.5.0)
# Requirement already satisfied: opentelemetry-instrumentation>=0.50b0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation-alephalpha==0.34.0->traceloop-sdk) (0.50b0)
# Requirement already satisfied: opentelemetry-semantic-conventions>=0.50b0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation-alephalpha==0.34.0->traceloop-sdk) (0.50b0)
# Requirement already satisfied: anthropic>=0.17.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation-bedrock==0.34.0->traceloop-sdk) (0.39.0)
# Requirement already satisfied: inflection<0.6.0,>=0.5.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation-llamaindex==0.34.0->traceloop-sdk) (0.5.1)
# Requirement already satisfied: tiktoken<1,>=0.6.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation-openai==0.34.0->traceloop-sdk) (0.7.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.10.9->traceloop-sdk) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.10.9->traceloop-sdk) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.10.9->traceloop-sdk) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.10.9->traceloop-sdk) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.10.9->traceloop-sdk) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.10.9->traceloop-sdk) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from aiohttp<4.0.0,>=3.10.9->traceloop-sdk) (1.17.1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from deprecated<2.0.0,>=1.2.14->traceloop-sdk) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from jinja2<4.0.0,>=3.1.2->traceloop-sdk) (3.0.2)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-api<2.0.0,>=1.28.0->traceloop-sdk) (8.4.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.28.0->traceloop-sdk) (1.63.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.28.0->traceloop-sdk) (1.67.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.28.0->traceloop-sdk) (1.29.0)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.28.0->traceloop-sdk) (1.29.0)
# Requirement already satisfied: protobuf<6.0,>=5.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-proto==1.29.0->opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.28.0->traceloop-sdk) (5.29.2)
# Requirement already satisfied: requests~=2.7 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.28.0->traceloop-sdk) (2.32.3)
# Requirement already satisfied: packaging>=18.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation>=0.50b0->opentelemetry-instrumentation-alephalpha==0.34.0->traceloop-sdk) (23.2)
# Requirement already satisfied: opentelemetry-util-http==0.50b0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-instrumentation-requests>=0.50b0->traceloop-sdk) (0.50b0)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from opentelemetry-sdk<2.0.0,>=1.28.0->traceloop-sdk) (4.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from posthog<4,>3.0.2->traceloop-sdk) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from posthog<4,>3.0.2->traceloop-sdk) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from posthog<4,>3.0.2->traceloop-sdk) (2.2.1)
# Requirement already satisfied: python-dateutil>2.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from posthog<4,>3.0.2->traceloop-sdk) (2.8.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from pydantic>=1->traceloop-sdk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from pydantic>=1->traceloop-sdk) (2.23.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from anthropic>=0.17.0->opentelemetry-instrumentation-bedrock==0.34.0->traceloop-sdk) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from anthropic>=0.17.0->opentelemetry-instrumentation-bedrock==0.34.0->traceloop-sdk) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from anthropic>=0.17.0->opentelemetry-instrumentation-bedrock==0.34.0->traceloop-sdk) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from anthropic>=0.17.0->opentelemetry-instrumentation-bedrock==0.34.0->traceloop-sdk) (0.7.0)
# Requirement already satisfied: sniffio in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from anthropic>=0.17.0->opentelemetry-instrumentation-bedrock==0.34.0->traceloop-sdk) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api<2.0.0,>=1.28.0->traceloop-sdk) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.28.0->traceloop-sdk) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.28.0->traceloop-sdk) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.28.0->traceloop-sdk) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.28.0->traceloop-sdk) (2024.8.30)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from tiktoken<1,>=0.6.0->opentelemetry-instrumentation-openai==0.34.0->traceloop-sdk) (2024.11.6)
# Requirement already satisfied: httpcore==1.* in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpx<1,>=0.23.0->anthropic>=0.17.0->opentelemetry-instrumentation-bedrock==0.34.0->traceloop-sdk) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\muthu\.conda\envs\llamaindex\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->anthropic>=0.17.0->opentelemetry-instrumentation-bedrock==0.34.0->traceloop-sdk) (0.14.0)

# %%
import os
from llama_index.core import Settings
from llama_index.llms.ollama import Ollama
from llama_index.embeddings.ollama import OllamaEmbedding

# Configure Ollama LLM
ollama_llm = Ollama(
    #model="llama3.2:latest",
    model="mistral:7b",
    base_url="http://localhost:11434",
    temperature=0.1
)

# Configure embedding model
ollama_embedding = OllamaEmbedding(
    model_name="nomic-embed-text:latest",
    base_url="http://localhost:11434",
    ollama_additional_kwargs={"mirostat": 0}
)

Settings.llm = ollama_llm
Settings.embed_model = ollama_embedding

# %%
import getpass
import os

os.environ["TRACELOOP_API_KEY"] = getpass.getpass("traceloop api key: ")

# %%
from traceloop.sdk import Traceloop

Traceloop.init()
# Out:
# Traceloop exporting traces to https://api.traceloop.com authenticating with bearer token
#
# ERROR:root:Error initializing LangChain instrumentor: No module named 'langchain_openai'
# Error initializing LangChain instrumentor: No module named 'langchain_openai'
# ERROR:root:Error initializing redis instrumentor: No module named 'opentelemetry.instrumentation.redis'
# Error initializing redis instrumentor: No module named 'opentelemetry.instrumentation.redis'

# %%
from llama_index.core import SimpleDirectoryReader

#documents = SimpleDirectoryReader(input_files=['../data/2022 Q3 AAPL.pdf']).load_data()
documents = SimpleDirectoryReader(input_files=['../data/paul_graham_essay3.txt']).load_data()

# %%
from llama_index.core import VectorStoreIndex

index = VectorStoreIndex.from_documents(documents)
query_engine = index.as_query_engine()
response = query_engine.query("What did the author do growing up?")
print(response)
# Out:
#  The author, Paul Graham, grew up working on two main things outside of school: writing short stories and programming. He started programming in 9th grade using an early version of Fortran on an IBM 1401 computer. Later, he got a microcomputer, a TRS-80, in about 1980 which he used extensively for programming. He also studied philosophy in college but later switched to AI due to his interest in artificial intelligence and intelligent computers.
